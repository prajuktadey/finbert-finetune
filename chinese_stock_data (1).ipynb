# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://edition.cnn.com/2024/02/06/investing/china-stocks-rally-government-stimulus/index.html'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content,'html.parser')
text = soup.get_text()

# %%
text
# Out:
# " \n\n\n\n\n\n\n\n\nChina is pumping money into stocks and markets are loving it | CNN Business\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCNN values your feedback\n\n\n\n\n                                                        1. How relevant is this ad to you?\n                                                \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                2. Did you encounter any technical issues?\n                                        \n\n\n\n\n\n\n\n\n\n\n\n                                                                        Video player was slow to load content\n                                                                        \n\n\n\n                                                                        Video content never loaded\n                                                                        \n\n\n\n                                                                        Ad froze or did not finish loading\n                                                                        \n\n\n\n                                                                        Video content did not start after ad\n                                                                        \n\n\n\n                                                                        Audio on ad was too loud\n                                                                        \n\n\n\n                                                                        Other issues\n                                                                        \n\n\n\n\n\n                                                                        Ad never loaded\n                                                                        \n\n\n\n                                                                        Ad prevented/slowed the page from loading\n                                                                        \n\n\n\n                                                                        Content moved around while ad loaded\n                                                                        \n\n\n\n                                                                        Ad was repetitive to ads I've seen previously\n                                                                        \n\n\n\n                                                                        Other issues\n                                                                        \n\n\n\n\n\n\n\n\n\n\n\n                                                        Cancel\n                                                \n\n                                                        Submit\n                                                \n\n\n\n\n\nThank You!\n\n                                        Your effort and contribution in providing this feedback is much\n                                        appreciated.\n                                \n\n                                        Close\n                                \n\n\n\n\n\n\n\n\n\n\n\nAd Feedback\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nClose icon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                  \n                  Markets\n                \n\n\n\n                  \n                  Tech\n                \n\n\n\n                  \n                  Media\n                \n\n\n\n                  \n                  Calculators\n                \n\n\n\n                  \n                  Videos\n                \n\n\n\n                  More\n                \n\n\n                    Markets\n                  \n\n                    Tech\n                  \n\n                    Media\n                  \n\n                    Calculators\n             ...

# %%
from transformers import BertTokenizer,BertForSequenceClassification

# %%
from transformers import pipeline

# %%
tokenizer = BertTokenizer.from_pretrained("ahmedrachid/FinancialBERT-Sentiment-Analysis")
tokens = tokenizer(text, return_tensors="pt")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/369 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/464k [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2688 > 512). Running this sequence through the model will result in indexing errors

# %%
model = BertForSequenceClassification.from_pretrained("ahmedrachid/FinancialBERT-Sentiment-Analysis", num_labels=3)
# Out:
# config.json:   0%|          | 0.00/789 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]

# %%
import requests
from bs4 import BeautifulSoup
import torch
from transformers import BertTokenizer, BertForSequenceClassification

# %%
def analyze_sentiment(sentence, model, tokenizer):
    tokens = tokenizer(sentence, truncation=True, return_tensors="pt", max_length=512)
    tokens['input_ids'] = tokens['input_ids'][:, :512]

    outputs = model(**tokens)
    logits = outputs.logits
    probs = torch.nn.functional.softmax(logits, dim=-1)

    predicted_label = torch.argmax(probs, dim=-1).item()
    sentiment_text = {0: 'Negative', 1: 'Neutral', 2: 'Positive'}[predicted_label]
    confidence_score = probs[0, predicted_label].item()

    return {'label': sentiment_text, 'score': confidence_score}

# %%
model = BertForSequenceClassification.from_pretrained("ahmedrachid/FinancialBERT-Sentiment-Analysis", num_labels=3)
tokenizer = BertTokenizer.from_pretrained("ahmedrachid/FinancialBERT-Sentiment-Analysis")

url = 'https://edition.cnn.com/2024/02/06/investing/china-stocks-rally-government-stimulus/index.html'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
paragraphs = soup.find_all('p')
text = ' '.join([paragraph.get_text() for paragraph in paragraphs])

sentences = text.split('.')
sentiment_results = []

# %%
#analyses the sentiment of non-empty sentences
for i, sentence in enumerate(sentences, start=1):
    if not sentence.strip():
        continue

    sentiment_result = analyze_sentiment(sentence, model, tokenizer)

    sentiment_results.append({
        'sentence_number': i,
        'sentence': sentence,
        'sentiment': sentiment_result
    })

# %%
for result in sentiment_results:
    print(f"Sentence {result['sentence_number']}: {result['sentence']}")
    print(f"Sentiment: {result['sentiment']}")
    print("\n")
# Out:
# Sentence 1: Markets
#
#
#  Hot Stocks
#
#
#  Fear & Greed Index
#
#
#
#             Latest Market News
#
#
#
#             Hot Stocks
#
#
#
#   Editor’s Note: Sign up for CNN’s Meanwhile in China newsletter, which explores what you need to know about the country’s rise and how it impacts the world
# Sentiment: {'label': 'Neutral', 'score': 0.9997771382331848}
#
#
# Sentence 2:
#
#             Chinese stocks staged their biggest rally in years Tuesday, after the country’s sovereign wealth fund said it would step up buying shares as officials scramble to draw a line under a three-year market rout
# Sentiment: {'label': 'Positive', 'score': 0.9980061650276184}
#
#
# Sentence 3:
#
#             The Shanghai Composite, mainland China’s benchmark index for large state-owned companies and blue-chip stocks, ended up 3
# Sentiment: {'label': 'Positive', 'score': 0.9996092915534973}
#
#
# Sentence 4: 2% on Tuesday, ending a six-day losing streak
# Sentiment: {'label': 'Negative', 'score': 0.9931215643882751}
#
#
# Sentence 5:  It marks the biggest daily increase since March 2022
# Sentiment: {'label': 'Positive', 'score': 0.9997623562812805}
#
#
# Sentence 6:
#
#             Smaller companies did even better
# Sentiment: {'label': 'Positive', 'score': 0.9974403381347656}
#
#
# Sentence 7:  The Shenzhen Component Index rose 6
# Sentiment: {'label': 'Positive', 'score': 0.9998424053192139}
#
#
# Sentence 8: 2%
# Sentiment: {'label': 'Neutral', 'score': 0.9932981133460999}
#
#
# Sentence 9:  It was the index’s best daily gain since September 2015, while startup index ChiNext had its best performance in seven years, soaring 6
# Sentiment: {'label': 'Positive', 'score': 0.9997808337211609}
#
#
# Sentence 10: 7%
# Sentiment: {'label': 'Neutral', 'score': 0.9838420152664185}
#
#
# Sentence 11:
#
#             In Hong Kong, the Hang Seng Index surged 4%, the biggest percentage gain in more than six months
# Sentiment: {'label': 'Positive', 'score': 0.9997721314430237}
#
#
# Sentence 12:  Chinese tech shares led the way
# Sentiment: {'label': 'Positive', 'score': 0.9994382262229919}
#
#
# Sentence 13:  Alibaba Group (BABA), which is due to announce earnings on Wednesday, was up 7
# Sentiment: {'label': 'Positive', 'score': 0.9998263716697693}
#
#
# Sentence 14: 6%
# Sentiment: {'label': 'Neutral', 'score': 0.9799278974533081}
#
#
# Sentence 15:
#
#             The positive mood spilled over to Europe, where the region’s benchmark Stoxx 600 index opened about 0
# Sentiment: {'label': 'Positive', 'score': 0.9603947997093201}
#
#
# Sentence 16: 5% higher, before trimming those early gains to stand 0
# Sentiment: {'label': 'Positive', 'score': 0.9964935183525085}
#
#
# Sentence 17: 1% up by 5
# Sentiment: {'label': 'Neutral', 'score': 0.9920558333396912}
#
#
# Sentence 18: 44 a
# Sentiment: {'label': 'Neutral', 'score': 0.6731131672859192}
#
#
# Sentence 19: m
# Sentiment: {'label': 'Neutral', 'score': 0.9940635561943054}
#
#
# Sentence 20:  ET
# Sentiment: {'label': 'Neutral', 'score': 0.9890240430831909}
#
#
# Sentence 21:  US stock futures were mixed
# Sentiment: {'label': 'Positive', 'score': 0.9217436909675598}
#
#
# Sentence 22:
#
# Related article
# Angry Chinese take to US Embassy’s social media account to vent about plunging stock market
#
#             The rebound in Chinese stocks came after Beijing stepped up its efforts to prop up the ailing stock market, which had a dire 2023 and has been the worst performer in the world so far this year
# Sentiment: {'label': 'Positive', 'score': 0.9995162487030029}
#
#
# Sentence 23:
#
#             By Monday, about $6
# Sentiment: {'label': 'Neutral', 'score': 0.9993594288825989}
#
#
# Sentence 24: 1 trillion in market value had been wiped from the Chinese and Hong Kong stock markets since their recent peaks in February 2021
# Sentiment: {'label': 'Neutral', 'score': 0.9946256279945374}
#
#
# Sentence 25:
#
#             Central Huijin Investment, the equity arm of state-owned China Investment Corp, announced Tuesday that it had recently expanded its holdings of exchange-traded funds (ETFs) on mainland stock markets
# Sentiment: {'label': 'Positive', 'score': 0.9996249675750732}
#
#
# Sentence 26:
#
#             “We will continue to increase our holdings and expand our holdings to resolutely maintain the stable operations of the capital market,” it said in a statement
# Sentiment: {'label': 'Positive', 'score': 0.9998363256454468}
#
#
# Sentence 27:
#
#             Shortly after the announcement, the China Securities Regulatory Commission issued a statement saying it “firmly supports” Central Huijin Investment in its plan to continue to increase the scale of its holdings
# Sentiment: {'label': 'Positive', 'score': 0.9983856678009033}
#
#
# Sentence 28:
#
#             The regulator said it would also encourage more institutional investors, such as mutual funds, state pension funds and insurers, to enter the stock market, the CSRC added
# Sentiment: {'label': 'Neutral', 'score': 0.8688535094261169}
#
#
# Sentence 29:
#
#             The intensified efforts came after Chinese markets resumed their slide on Monday, when more than 1,800 stocks fell by more than 10% in Shanghai and Shenzhen
# Sentiment: {'label': 'Negative', 'score': 0.9913390278816223}
#
#
# Sentence 30:
#
#             Angry investors flocked to a social media account of the US Embassy in Beijing to vent their outrage about the meltdown of the stock market, after other outlets of protest had been closed off
# Sentiment: {'label': 'Negative', 'score': 0.9597209692001343}
#
#
# Sentence 31:
#
# Related article
# US sends top Treasury officials to China to discuss economy
#
#             Tuesday’s rally in China was in contrast to other markets in the region
# Sentiment: {'label': 'Neutral', 'score': 0.9926579594612122}
#
#
# Sentence 32:  Japan’s Nikkei and South Korea’s Kospi closed down 0
# Sentiment: {'label': 'Negative', 'score': 0.9945764541625977}
#
#
# Sentence 33: 5% and 0
# Sentiment: {'label': 'Neutral', 'score': 0.9950270056724548}
#
#
# Sentence 34: 6% respectively
# Sentiment: {'label': 'Neutral', 'score': 0.9977748990058899}
#
#
# Sentence 35:  Australia’s S&P/ASX 200 also lost 0
# Sentiment: {'label': 'Negative', 'score': 0.9992484450340271}
#
#
# Sentence 36: 6%
# Sentiment: {'label': 'Neutral', 'score': 0.9799278974533081}
#
#
# Sentence 37:
#
#             The redoubled attempts to rescue Chinese stocks appear to have bought Beijing some more time, but they don’t address the underlying challenges the economy faces — weak demand, deflationary pressures, a crashed real estate sector, and rising trade tensions with the United States
# Sentiment: {'label': 'Negative', 'score': 0.9768235683441162}
#
#
# Sentence 38:
#
#             A brief period of market calm following soothing words from Beijing was brought to an abrupt end late last month when a Hong Kong court ordered Evergrande, the poster child of China’s property crisis, to liquidate
# Sentiment: {'label': 'Negative', 'score': 0.9433835744857788}
#
#
# Sentence 39:  That sent investors running for the exits again
# Sentiment: {'label': 'Neutral', 'score': 0.9997171759605408}
#
#
# Sentence 40:
#
# Anna Cooban contributed to this article
# Sentiment: {'label': 'Neutral', 'score': 0.9997380375862122}
#
#
# Sentence 41:
#  Most stock quote data provided by BATS
# Sentiment: {'label': 'Neutral', 'score': 0.9996647834777832}
#
#
# Sentence 42:  US market indices are shown in real time, except for the S&P 500 which is refreshed every two minutes
# Sentiment: {'label': 'Neutral', 'score': 0.9996587038040161}
#
#
# Sentence 43:  All times are ET
# Sentiment: {'label': 'Neutral', 'score': 0.9992775321006775}
#
#
# Sentence 44:  Factset: FactSet Research Systems Inc
# Sentiment: {'label': 'Neutral', 'score': 0.998114824295044}
#
#
# Sentence 45:  All rights reserved
# Sentiment: {'label': 'Neutral', 'score': 0.9996082186698914}
#
#
# Sentence 46:  Chicago Mercantile: Certain market data is the property of Chicago Mercantile Exchange Inc
# Sentiment: {'label': 'Neutral', 'score': 0.9998154044151306}
#
#
# Sentence 47:  and its licensors
# Sentiment: {'label': 'Neutral', 'score': 0.9078153967857361}
#
#
# Sentence 48:  All rights reserved
# Sentiment: {'label': 'Neutral', 'score': 0.9996082186698914}
#
#
# Sentence 49:  Dow Jones: The Dow Jones branded indices are proprietary to and are calculated, distributed and marketed by DJI Opco, a subsidiary of S&P Dow Jones Indices LLC and have been licensed for use to S&P Opco, LLC and CNN
# Sentiment: {'label': 'Neutral', 'score': 0.9997455477714539}
#
#
# Sentence 50:  Standard & Poor’s and S&P are registered trademarks of Standard & Poor’s Financial Services LLC and Dow Jones is a registered trademark of Dow Jones Trademark Holdings LLC
# Sentiment: {'label': 'Neutral', 'score': 0.9993385672569275}
#
#
# Sentence 51:  All content of the Dow Jones branded indices Copyright S&P Dow Jones Indices LLC and/or its affiliates
# Sentiment: {'label': 'Neutral', 'score': 0.999505877494812}
#
#
# Sentence 52:  Fair value provided by IndexArb
# Sentiment: {'label': 'Neutral', 'score': 0.9996829032897949}
#
#
# Sentence 53: com
# Sentiment: {'label': 'Neutral', 'score': 0.9890037178993225}
#
#
# Sentence 54:  Market holidays and trading hours provided by Copp Clark Limited
# Sentiment: {'label': 'Neutral', 'score': 0.9995123147964478}
#
#
# Sentence 55:  © 2024 Cable News Network
# Sentiment: {'label': 'Neutral', 'score': 0.9996720552444458}
#
#
# Sentence 56:  A Warner Bros
# Sentiment: {'label': 'Neutral', 'score': 0.9991313815116882}
#
#
# Sentence 57:  Discovery Company
# Sentiment: {'label': 'Neutral', 'score': 0.9986170530319214}
#
#
# Sentence 58:  All Rights Reserved
# Sentiment: {'label': 'Neutral', 'score': 0.9991707801818848}
#
#
# Sentence 59:   CNN Sans ™ & © 2016 Cable News Network
# Sentiment: {'label': 'Neutral', 'score': 0.9995446801185608}
#
#
# Sentence 1: Markets
#
#
#  Hot Stocks
#
#
#  Fear & Greed Index
#
#
#
#             Latest Market News
#
#
#
#             Hot Stocks
#
#
#
#   Editor’s Note: Sign up for CNN’s Meanwhile in China newsletter, which explores what you need to know about the country’s rise and how it impacts the world
# Sentiment: {'label': 'Neutral', 'score': 0.9997771382331848}
#
#
# Sentence 2:
#
#             Chinese stocks staged their biggest rally in years Tuesday, after the country’s sovereign wealth fund said it would step up buying shares as officials scramble to draw a line under a three-year market rout
# Sentiment: {'label': 'Positive', 'score': 0.9980061650276184}
#
#
# Sentence 3:
#
#             The Shanghai Composite, mainland China’s benchmark index for large state-owned companies and blue-chip stocks, ended up 3
# Sentiment: {'label': 'Positive', 'score': 0.9996092915534973}
#
#
# Sentence 4: 2% on Tuesday, ending a six-day losing streak
# Sentiment: {'label': 'Negative', 'score': 0.9931215643882751}
#
#
# Sentence 5:  It marks the biggest daily increase since March 2022
# Sentiment: {'label': 'Positive', 'score': 0.9997623562812805}
#
#
# Sentence 6:
#
#             Smaller companies did even better
# Sentiment: {'label': 'Positive', 'score': 0.9974403381347656}
#
#
# Sentence 7:  The Shenzhen Component Index rose 6
# Sentiment: {'label': 'Positive', 'score': 0.9998424053192139}
#
#
# Sentence 8: 2%
# Sentiment: {'label': 'Neutral', 'score': 0.9932981133460999}
#
#
# Sentence 9:  It was the index’s best daily gain since September 2015, while startup index ChiNext had its best performance in seven years, soaring 6
# Sentiment: {'label': 'Positive', 'score': 0.9997808337211609}
#
#
# Sentence 10: 7%
# Sentiment: {'label': 'Neutral', 'score': 0.9838420152664185}
#
#
# Sentence 11:
#
#             In Hong Kong, the Hang Seng Index surged 4%, the biggest percentage gain in more than six months
# Sentiment: {'label': 'Positive', 'score': 0.9997721314430237}
#
#
# Sentence 12:  Chinese tech shares led the way
# Sentiment: {'label': 'Positive', 'score': 0.9994382262229919}
#
#
# Sentence 13:  Alibaba Group (BABA), which is due to announce earnings on Wednesday, was up 7
# Sentiment: {'label': 'Positive', 'score': 0.9998263716697693}
#
#
# Sentence 14: 6%
# Sentiment: {'label': 'Neutral', 'score': 0.9799278974533081}
#
#
# Sentence 15:
#
#             The positive mood spilled over to Europe, where the region’s benchmark Stoxx 600 index opened about 0
# Sentiment: {'label': 'Positive', 'score': 0.9603947997093201}
#
#
# Sentence 16: 5% higher, before trimming those early gains to stand 0
# Sentiment: {'label': 'Positive', 'score': 0.9964935183525085}
#
#
# Sentence 17: 1% up by 5
# Sentiment: {'label': 'Neutral', 'score': 0.9920558333396912}
#
#
# Sentence 18: 44 a
# Sentiment: {'label': 'Neutral', 'score': 0.6731131672859192}
#
#
# Sentence 19: m
# Sentiment: {'label': 'Neutral', 'score': 0.9940635561943054}
#
#
# Sentence 20:  ET
# Sentiment: {'label': 'Neutral', 'score': 0.9890240430831909}
#
#
# Sentence 21:  US stock futures were mixed
# Sentiment: {'label': 'Positive', 'score': 0.9217436909675598}
#
#
# Sentence 22:
#
# Related article
# Angry Chinese take to US Embassy’s social media account to vent about plunging stock market
#
#             The rebound in Chinese stocks came after Beijing stepped up its efforts to prop up the ailing stock market, which had a dire 2023 and has been the worst performer in the world so far this year
# Sentiment: {'label': 'Positive', 'score': 0.9995162487030029}
#
#
# Sentence 23:
#
#             By Monday, about $6
# Sentiment: {'label': 'Neutral', 'score': 0.9993594288825989}
#
#
# Sentence 24: 1 trillion in market value had been wiped from the Chinese and Hong Kong stock markets since their recent peaks in February 2021
# Sentiment: {'label': 'Neutral', 'score': 0.9946256279945374}
#
#
# Sentence 25:
#
#             Central Huijin Investment, the equity arm of state-owned China Investment Corp, announced Tuesday that it had recently expanded its holdings of exchange-traded funds (ETFs) on mainland stock markets
# Sentiment: {'label': 'Positive', 'score': 0.9996249675750732}
#
#
# Sentence 26:
#
#             “We will continue to increase our holdings and expand our holdings to resolutely maintain the stable operations of the capital market,” it said in a statement
# Sentiment: {'label': 'Positive', 'score': 0.9998363256454468}
#
#
# Sentence 27:
#
#             Shortly after the announcement, the China Securities Regulatory Commission issued a statement saying it “firmly supports” Central Huijin Investment in its plan to continue to increase the scale of its holdings
# Sentiment: {'label': 'Positive', 'score': 0.9983856678009033}
#
#
# Sentence 28:
#
#             The regulator said it would also encourage more institutional investors, such as mutual funds, state pension funds and insurers, to enter the stock market, the CSRC added
# Sentiment: {'label': 'Neutral', 'score': 0.8688535094261169}
#
#
# Sentence 29:
#
#             The intensified efforts came after Chinese markets resumed their slide on Monday, when more than 1,800 stocks fell by more than 10% in Shanghai and Shenzhen
# Sentiment: {'label': 'Negative', 'score': 0.9913390278816223}
#
#
# Sentence 30:
#
#             Angry investors flocked to a social media account of the US Embassy in Beijing to vent their outrage about the meltdown of the stock market, after other outlets of protest had been closed off
# Sentiment: {'label': 'Negative', 'score': 0.9597209692001343}
#
#
# Sentence 31:
#
# Related article
# US sends top Treasury officials to China to discuss economy
#
#             Tuesday’s rally in China was in contrast to other markets in the region
# Sentiment: {'label': 'Neutral', 'score': 0.9926579594612122}
#
#
# Sentence 32:  Japan’s Nikkei and South Korea’s Kospi closed down 0
# Sentiment: {'label': 'Negative', 'score': 0.9945764541625977}
#
#
# Sentence 33: 5% and 0
# Sentiment: {'label': 'Neutral', 'score': 0.9950270056724548}
#
#
# Sentence 34: 6% respectively
# Sentiment: {'label': 'Neutral', 'score': 0.9977748990058899}
#
#
# Sentence 35:  Australia’s S&P/ASX 200 also lost 0
# Sentiment: {'label': 'Negative', 'score': 0.9992484450340271}
#
#
# Sentence 36: 6%
# Sentiment: {'label': 'Neutral', 'score': 0.9799278974533081}
#
#
# Sentence 37:
#
#             The redoubled attempts to rescue Chinese stocks appear to have bought Beijing some more time, but they don’t address the underlying challenges the economy faces — weak demand, deflationary pressures, a crashed real estate sector, and rising trade tensions with the United States
# Sentiment: {'label': 'Negative', 'score': 0.9768235683441162}
#
#
# Sentence 38:
#
#             A brief period of market calm following soothing words from Beijing was brought to an abrupt end late last month when a Hong Kong court ordered Evergrande, the poster child of China’s property crisis, to liquidate
# Sentiment: {'label': 'Negative', 'score': 0.9433835744857788}
#
#
# Sentence 39:  That sent investors running for the exits again
# Sentiment: {'label': 'Neutral', 'score': 0.9997171759605408}
#
#
# Sentence 40:
#
# Anna Cooban contributed to this article
# Sentiment: {'label': 'Neutral', 'score': 0.9997380375862122}
#
#
# Sentence 41:
#  Most stock quote data provided by BATS
# Sentiment: {'label': 'Neutral', 'score': 0.9996647834777832}
#
#
# Sentence 42:  US market indices are shown in real time, except for the S&P 500 which is refreshed every two minutes
# Sentiment: {'label': 'Neutral', 'score': 0.9996587038040161}
#
#
# Sentence 43:  All times are ET
# Sentiment: {'label': 'Neutral', 'score': 0.9992775321006775}
#
#
# Sentence 44:  Factset: FactSet Research Systems Inc
# Sentiment: {'label': 'Neutral', 'score': 0.998114824295044}
#
#
# Sentence 45:  All rights reserved
# Sentiment: {'label': 'Neutral', 'score': 0.9996082186698914}
#
#
# Sentence 46:  Chicago Mercantile: Certain market data is the property of Chicago Mercantile Exchange Inc
# Sentiment: {'label': 'Neutral', 'score': 0.9998154044151306}
#
#
# Sentence 47:  and its licensors
# Sentiment: {'label': 'Neutral', 'score': 0.9078153967857361}
#
#
# Sentence 48:  All rights reserved
# Sentiment: {'label': 'Neutral', 'score': 0.9996082186698914}
#
#
# Sentence 49:  Dow Jones: The Dow Jones branded indices are proprietary to and are calculated, distributed and marketed by DJI Opco, a subsidiary of S&P Dow Jones Indices LLC and have been licensed for use to S&P Opco, LLC and CNN
# Sentiment: {'label': 'Neutral', 'score': 0.9997455477714539}
#
#
# Sentence 50:  Standard & Poor’s and S&P are registered trademarks of Standard & Poor’s Financial Services LLC and Dow Jones is a registered trademark of Dow Jones Trademark Holdings LLC
# Sentiment: {'label': 'Neutral', 'score': 0.9993385672569275}
#
#
# Sentence 51:  All content of the Dow Jones branded indices Copyright S&P Dow Jones Indices LLC and/or its affiliates
# Sentiment: {'label': 'Neutral', 'score': 0.999505877494812}
#
#
# Sentence 52:  Fair value provided by IndexArb
# Sentiment: {'label': 'Neutral', 'score': 0.9996829032897949}
#
#
# Sentence 53: com
# Sentiment: {'label': 'Neutral', 'score': 0.9890037178993225}
#
#
# Sentence 54:  Market holidays and trading hours provided by Copp Clark Limited
# Sentiment: {'label': 'Neutral', 'score': 0.9995123147964478}
#
#
# Sentence 55:  © 2024 Cable News Network
# Sentiment: {'label': 'Neutral', 'score': 0.9996720552444458}
#
#
# Sentence 56:  A Warner Bros
# Sentiment: {'label': 'Neutral', 'score': 0.9991313815116882}
#
#
# Sentence 57:  Discovery Company
# Sentiment: {'label': 'Neutral', 'score': 0.9986170530319214}
#
#
# Sentence 58:  All Rights Reserved
# Sentiment: {'label': 'Neutral', 'score': 0.9991707801818848}
#
#
# Sentence 59:   CNN Sans ™ & © 2016 Cable News Network
# Sentiment: {'label': 'Neutral', 'score': 0.9995446801185608}

# %%
pos = 0
neg = 0

for result in sentiment_results:
    sentimentlabel = result['sentiment']['label']

    if sentimentlabel == 'Positive':
        pos += 1
    elif sentimentlabel == 'Negative':
        neg += 1

if pos > neg:
  collectivesentiment = 'Positive'
elif neg > pos:
  collectivesentiment = 'Negative'

# %%
print("Collective Sentiment:")
print(f"Positive Count: {pos}")
print(f"Negative Count: {neg}")
print(f"Collective Sentiment: {collectivesentiment}")
# Out:
# Collective Sentiment:
# Positive Count: 48
# Negative Count: 21
# Collective Sentiment: Positive

# %%
#text summarization
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# %%
print(summarizer(text[:1024], max_length=130, min_length=30, do_sample=False))
# Out:
# [{'summary_text': 'Chinese stocks staged their biggest rally in years Tuesday, ending a six-day losing streak. The Shanghai Composite, mainland China’s benchmark index for large state-owned companies and blue-chip stocks, ended up 3.2%. It marks the biggest daily increase since March 2022. Smaller companies did even better.'}]
